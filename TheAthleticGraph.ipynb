# %% [markdown]
# <a href="https://colab.research.google.com/github/nSandyB/nn-beginning/blob/master/TheAthleticGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mplsoccer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import VerticalPitch

# %%
df = pd.read_csv('erling_haaland_2022_understat.csv')

# %%
df.head()
# Out:
#        id  minute       result      X      Y        xG          player h_a  \
# 0  479846      20  MissedShots  0.936  0.503  0.484085  Erling Haaland   a
# 1  479847      35         Goal  0.885  0.500  0.761169  Erling Haaland   a
# 2  479854      64         Goal  0.864  0.405  0.328053  Erling Haaland   a
# 3  479855      69  MissedShots  0.953  0.552  0.526608  Erling Haaland   a
# 4  479856      75  BlockedShot  0.894  0.710  0.066443  Erling Haaland   a
#
#    player_id situation  season  shotType  match_id    h_team           a_team  \
# 0       8260  OpenPlay    2022      Head     18211  West Ham  Manchester City
# 1       8260   Penalty    2022  LeftFoot     18211  West Ham  Manchester City
# 2       8260  OpenPlay    2022  LeftFoot     18211  West Ham  Manchester City
# 3       8260  OpenPlay    2022      Head     18211  West Ham  Manchester City
# 4       8260  OpenPlay    2022  LeftFoot     18211  West Ham  Manchester City
#
# ...

# %%
df['X'] = df['X']*100
df['Y'] = df['Y']*100

# %%
total_shots = df.shape[0]
total_goals= df[df['result']=='scored'].shape[0]
total_xG = df['xG'].sum()
xG_per_shot = total_xG/total_shots
points_average_distance = df['X'].mean()
actual_avg_distance = 120-(df['X']*1.2).mean()

# %%
actual_avg_distance
# Out:
# 11.720000401938833

# %%
background_color = '#0C0D0E'

# %%
import matplotlib.font_manager as font_manager

font_props = font_manager.FontProperties(fname='arvo-regular.ttf')

# %%
fig = plt.figure(figsize=(8,12))
fig.patch.set_facecolor(background_color)
ax1  = fig.add_axes([0,0.7,1,.2])
ax1.set_facecolor(background_color)
ax1.set_xlim(0,1)
ax1.set_ylim(0,1)

ax1.text(
    x=0.5,
    y=.85,
    s='Erling Haaland',
    fontsize = 20,
    fontproperties=font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'center'
)

ax1.text(
    x=0.5,
    y=.75,
    s='All shots in the Premier League 2022-23',
    fontsize = 14,
    fontproperties=font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'center'
)


ax1.text(
    x=0.25,
    y=.5,
    s='Low Quality Chance',
    fontsize = 12,
    fontproperties=font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'center'
)

ax1.scatter(
    x=.37,
    y=.53,
    s= 100,
    color = background_color,
    edgecolor = 'white',
    linewidth = 0.8
)

ax1.scatter(
    x=.42,
    y=.53,
    s= 200,
    color = background_color,
    edgecolor = 'white',
    linewidth = 0.8
)

ax1.scatter(
    x=.48,
    y=.53,
    s= 300,
    color = background_color,
    edgecolor = 'white',
    linewidth = 0.8
)

ax1.scatter(
    x=.54,
    y=.53,
    s= 400,
    color = background_color,
    edgecolor = 'white',
    linewidth = 0.8
)

ax1.scatter(
    x=.60,
    y=.53,
    s= 500,
    color = background_color,
    edgecolor = 'white',
    linewidth = 0.8
)

ax1.text(
    x=0.75,
    y=.5,
    s='High Quality Chance',
    fontsize = 12,
    fontproperties=font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'center'
)

ax1.text(
    x=0.45,
    y=.27,
    s=f'Goal',
    fontsize = 10,
    fontproperties=font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'right'
)

ax1.scatter(
    x=.47,
    y=.3,
    s= 100,
    color = 'red',
    edgecolor = 'white',
    linewidth = 0.8,
    alpha = .7
)

ax1.scatter(
    x=.53,
    y=.3,
    s= 100,
    color = background_color,
    edgecolor = 'white',
    linewidth = 0.8,
    alpha = .8
)

ax1.text(
    x=0.55,
    y=.27,
    s=f'No Goal',
    fontsize = 10,
    fontproperties=font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'left'
)





ax2  = fig.add_axes([0.05,0.25,0.9,.5])
ax2.set_facecolor(background_color)

pitch = VerticalPitch(
    pitch_type= 'opta',
    half = True,
    pitch_color = background_color,
    pad_bottom =.5,
    line_color= 'white',
    linewidth = .75,
    axis =True,
    label =True
)

pitch.draw(ax=ax2)

ax2.scatter(x=90, y= points_average_distance,
            s=100, color = 'white', linewidth =0.8)
ax2.plot([90,90], [100, points_average_distance], color = 'white', linewidth =2)

ax2.text(x=90, y= points_average_distance-4,
            s=f'Average Distance\n{actual_avg_distance:.1f}yards',
            fontsize=10, fontproperties= font_props,
         color = 'white', ha='center')


for x in df.to_dict(orient = 'records'):
  pitch.scatter(
      x['X'],
      x['Y'],
      s=300*x['xG'],
      color='red' if x['result']=='Goal' else background_color,
      ax=ax2,
      alpha = .7,
      edgecolor = 'white',
      linewidth = 0.8

  )


ax3  = fig.add_axes([0,0.2,1,.05])
ax3.set_facecolor(background_color)

ax3.text(x=.25, y=.5, s='shots', fontsize=20, fontproperties= font_props, fontweight = 'bold', color = 'white', ha = 'left')
ax3.text(x=.25, y= 0, s=f'{total_shots}', fontsize = 16, fontproperties=font_props, color='red', ha='left' )

ax3.text(x=.38, y=.5, s='Goals', fontsize=20, fontproperties= font_props, fontweight = 'bold', color = 'white', ha = 'left')
ax3.text(x=.38, y= 0, s=f'{total_goals}', fontsize = 16, fontproperties=font_props, color='red', ha='left' )

ax3.text(x=.53, y=.5, s='Total xG', fontsize=20, fontproperties= font_props, fontweight = 'bold', color = 'white', ha = 'left')
ax3.text(x=.53, y= 0, s=f'{total_xG: .2f}', fontsize = 16, fontproperties=font_props, color='red', ha='left' )

ax3.text(x=.73, y=.5, s='xG/Shot', fontsize=20, fontproperties= font_props, fontweight = 'bold', color = 'white', ha = 'left')
ax3.text(x=.73, y= 0, s=f'{xG_per_shot: .2f}', fontsize = 16, fontproperties=font_props, color='red', ha='left' )
# Out:
# Text(0.73, 0, ' 0.27')
